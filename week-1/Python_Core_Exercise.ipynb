# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# Task 1.1

raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)














    #task 1.2

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

#task 1.3

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)

#task 1.4

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update min and max
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)

#task 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)

#task 1.5.2

sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)


report_filename = os.path.join(reports_dir, "temperature_report.txt")

try:
    with open(report_filename, "w") as f:
        for reading_dict in temperature_readings:
            line = generate_report_line(reading_dict)
            f.write(line + "\n")

    print(f"Temperature report written to '{report_filename}'.")
except IOError as e:
    print(f"Error writing file '{report_filename}': {e}")


read_report_lines = []

try:
    with open(report_filename, "r") as f:
        read_report_lines = f.readlines()

    print("First 3 lines:")
    for line in read_report_lines[:3]:
        print(line.strip())

except IOError as e:
    print(f"Error reading file '{report_filename}': {e}")
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-15 13:30:28', 'DEV001', 'Humidity_Sensor', 'Lab2', 68.87)
# ('2026-07-15 13:30:28', 'DEV002', 'Light_Sensor', 'Warehouse', 446.6)
# ('2026-07-15 13:30:28', 'DEV003', 'Light_Sensor', 'Lab2', 139.52)
# ('2026-07-15 13:30:28', 'DEV004', 'Humidity_Sensor', 'OfficeA', 73.8)
# ('2026-07-15 13:30:28', 'DEV005', 'Pressure_Sensor', 'Lab1', 1027.33)
# [{'timestamp': '2026-07-15 13:30:28', 'device_id': 'DEV007', 'location': 'Warehouse', 'temperature_celsius': 23.43}, {'timestamp': '2026-07-15 13:30:28', 'device_id': 'DEV008', 'location': 'OfficeB', 'temperature_celsius': 29.25}, {'timestamp': '2026-07-15 13:30:28', 'device_id': 'DEV010', 'location': 'Warehouse', 'temperature_celsius': 21.05}, {'timestamp': '2026-07-15 13:30:28', 'device_id': 'DEV014', 'location': 'OfficeA', 'temperature_celsius': 19.76}, {'timestamp': '2026-07-15 13:30:28', 'device_id': 'DEV016', 'location': 'OfficeB', 'temperature_celsius': 22.65}]
# {'Lab2', 'Warehouse', 'OfficeB', 'OfficeA', 'Lab1'}
# {'Temperature_Sensor': (18.32, 29.42), 'Humidity_Sensor': (30.46, 80.0), 'Pressure_Sensor': (980.04, 1027.33), 'Light_Sensor': (107.1, 956.65)}
# [('2026-07-15 13:30:28', 'DEV010', 'Temperature_Sensor', 'Warehouse', 21.05), ('2026-07-15 13:30:28', 'DEV011', 'Light_Sensor', 'OfficeA', 585.48), ('2026-07-15 13:30:28', 'DEV012', 'Humidity_Sensor', 'Warehouse', 60.25), ('2026-07-15 13:30:28', 'DEV013', 'Humidity_Sensor', 'OfficeB', 45.68), ('2026-07-15 13:30:28', 'DEV014', 'Temperature_Sensor', 'OfficeA', 19.76), ('2026-07-15 13:30:28', 'DEV015', 'Light_Sensor', 'Warehouse', 348.46), ('2026-07-15 13:30:28', 'DEV016', 'Temperature_Sensor', 'OfficeB', 22.65), ('2026-07-15 13:30:28', 'DEV017', 'Light_Sensor', 'Warehouse', 531.27), ('2026-07-15 13:30:28', 'DEV018', 'Pressure_Sensor', 'OfficeB', 1024.82), ('2026-07-15 13:30:28', 'DEV019', 'Light_Sensor', 'Lab1', 404.63), ('2026-07-15 13:30:28', 'DEV020', 'Humidity_Sensor', 'Lab2', 80.0)]
# [('2026-07-15 13:30:28', 'DEV001', 'Humidity_Sensor', 'Lab2', 68.87), ('2026-07-15 13:30:28', 'DEV006', 'Light_Sensor', 'Lab1', 273.54), ('2026-07-15 13:30:28', 'DEV011', 'Light_Sensor', 'OfficeA', 585.48), ('2026-07-15 13:30:28', 'DEV016', 'Temperature_Sensor', 'OfficeB', 22.65), ('2026-07-15 13:30:28', 'DEV021', 'Pressure_Sensor', 'OfficeB', 995.69), ('2026-07-15 13:30:28', 'DEV026', 'Humidity_Sensor', 'Lab2', 49.41), ('2026-07-15 13:30:28', 'DEV031', 'Light_Sensor', 'OfficeA', 471.53), ('2026-07-15 13:30:28', 'DEV036', 'Light_Sensor', 'Warehouse', 422.46), ('2026-07-15 13:30:28', 'DEV041', 'Light_Sensor', 'Warehouse', 802.73), ('2026-07-15 13:30:28', 'DEV046', 'Temperature_Sensor', 'Lab1', 20.14), ('2026-07-15 13:30:28', 'DEV051', 'Pressure_Sensor', 'OfficeA', 983.19), ('2026-07-15 13:30:28', 'DEV056', 'Humidity_Sensor', 'Warehouse', 43.36), ('2026-07-15 13:30:28', 'DEV061', 'Temperature_Sensor', 'Lab2', 20.54), ('2026-07-15 13:30:28', 'DEV066', 'Pressure_Sensor', 'OfficeB', 980.04), ('2026-07-15 13:30:28', 'DEV071', 'Temperature_Sensor', 'OfficeB', 23.25), ('2026-07-15 13:30:28', 'DEV076', 'Pressure_Sensor', 'OfficeB', 1007.32), ('2026-07-15 13:30:28', 'DEV081', 'Pressure_Sensor', 'Lab1', 1015.39), ('2026-07-15 13:30:28', 'DEV086', 'Light_Sensor', 'Lab1', 242.16), ('2026-07-15 13:30:28', 'DEV091', 'Light_Sensor', 'Lab1', 741.32), ('2026-07-15 13:30:28', 'DEV096', 'Temperature_Sensor', 'Warehouse', 22.39)]
# Programming
# nohtyP
# Pressure_Sensor
# Sensor
# Directory 'sensor_reports' already exists.
# Duration: 0 days, 0 hours, 0 minutes
# [189, 155, 182, 105, 190]
# Temperature report written to 'sensor_reports/temperature_report.txt'.
# First 3 lines:
# [2026-07-15 13:30:28] Device DEV007 at Warehouse: 23.43°C
# [2026-07-15 13:30:28] Device DEV008 at OfficeB: 29.25°C
# [2026-07-15 13:30:28] Device DEV010 at Warehouse: 21.05°C
